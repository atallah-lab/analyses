# %%
load('~/jackgl/sim-develop/data/gene_pdt_allsites.rda')
gene_pdt_allsites <- gene_pdt
load('~/jackgl/sim-develop/data/gene_pdt.rda')
gene_pdt_exons <- gene_pdt

# %%
par(mar=c(10,5,5,5))
barplot(gene_pdt_allsites$p[order(-gene_pdt_allsites$p)][1:30],names=gene_pdt_allsites$geneSym[order(-gene_pdt_allsites$p)][1:30],las=2)
options(repr.plot.width=9, repr.plot.height=5)
# Out:
# plot without title

# %%
par(mar=c(10,5,5,5))
barplot(gene_pdt_exons$p[order(-gene_pdt_exons$p)][1:30],names=gene_pdt_exons$geneSym[order(-gene_pdt_exons$p)][1:30],las=2)
options(repr.plot.width=9, repr.plot.height=5)
# Out:
# plot without title

# %%
gene_pdt_allsites <- gene_pdt_allsites[order(gene_pdt_allsites$geneSym),]
gene_pdt <- gene_pdt[order(gene_pdt$geneSym),]
sum(gene_pdt_allsites$p - gene_pdt$p)
# Out:
# [1] 2.874491e-17
